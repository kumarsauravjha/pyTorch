# %%
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
mean = [0.4914, 0.4822, 0.4465]
std = [0.2023, 0.1994, 0.2010]

# %%
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1,0.1)),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

# %%
train_dataset = datasets.CIFAR10(root='D:/STUDY/MS/DATS 6450 Computer Vision', train=True, download=False, transform=transform_train)

# %%
test_dataset = datasets.CIFAR10(root='D:/STUDY/MS/DATS 6450 Computer Vision', train=False, download=False, transform=transform_test)

# %%
valid_dataset, train_dataset = torch.utils.data.random_split(train_dataset, [5000, len(train_dataset) - 5000])

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
val_loader = DataLoader(valid_dataset, batch_size=128, shuffle=False)

# %%
base_hidden_units = 32
weight_decay = 1e-4

class CIFAR10CNN(nn.Module):
    def __init__(self):
        super(CIFAR10CNN, self).__init__()
        #CONV1
        self.conv1 = nn.Conv2d(3,base_hidden_units,3, padding=1)
        self.bn1 = nn.BatchNorm2d(base_hidden_units)

        #CONV2
        self.conv2 = nn.Conv2d(base_hidden_units,base_hidden_units,3, padding=1)
        self.bn2 = nn.BatchNorm2d(base_hidden_units)

        #CONV3
        self.conv3 = nn.Conv2d(base_hidden_units,base_hidden_units*2,3, padding=1)
        self.bn3 = nn.BatchNorm2d(base_hidden_units*2)

        #CONV4
        self.conv4 = nn.Conv2d(base_hidden_units*2,base_hidden_units*2,3, padding=1)
        self.bn4 = nn.BatchNorm2d(base_hidden_units*2)

        #CONV5
        self.conv5 = nn.Conv2d(base_hidden_units*2,base_hidden_units*4,3, padding=1)
        self.bn5 = nn.BatchNorm2d(base_hidden_units*4)

        #CONV6
        self.conv6 = nn.Conv2d(base_hidden_units*4,base_hidden_units*4,3, padding=1)
        self.bn6 = nn.BatchNorm2d(base_hidden_units*4)

        #FC1
        self.fc1 = nn.Linear(base_hidden_units*4*4*4, 10)

        self.dropout1 = nn.Dropout(0.2)
        self.dropout2 = nn.Dropout(0.3)
        self.dropout3 = nn.Dropout(0.4)
        
        self.pool = nn.MaxPool2d(2,2)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))

        x = self.dropout1(self.pool(x))

        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))

        x = self.dropout2(self.pool(x))

        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))

        x = self.dropout3(self.pool(x))

        x = x = x.view(x.size(0), -1)
        x = self.fc1(x)
        return x

# %%
model = CIFAR10CNN()
model
# Out:
# CIFAR10CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=2048, out_features=10, bias=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (dropout3): Dropout(p=0.4, inplace=False)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'cuda'

# %%
model.to(device)
# Out:
# CIFAR10CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=2048, out_features=10, bias=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (dropout3): Dropout(p=0.4, inplace=False)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=weight_decay)
criterion = nn.CrossEntropyLoss()

# %%
# Training loop
def train(model, train_loader, valid_loader, criterion, optimizer, epochs=125):
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        print(f'Epoch {epoch+1}/{epochs}, Training Loss: {epoch_loss:.4f}')

        # Validate the model
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in valid_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
# Validation Accuracy: 84.90%
# Epoch 87/125, Training Loss: 0.4090
# Validation Accuracy: 85.86%
# Epoch 88/125, Training Loss: 0.4008
# Validation Accuracy: 85.34%
# Epoch 89/125, Training Loss: 0.4010
# Validation Accuracy: 85.38%
# Epoch 90/125, Training Loss: 0.3983
# Validation Accuracy: 85.94%
# Epoch 91/125, Training Loss: 0.3992
# Validation Accuracy: 85.28%
# Epoch 92/125, Training Loss: 0.4059
# Validation Accuracy: 85.86%
# Epoch 93/125, Training Loss: 0.4012
# Validation Accuracy: 84.08%
# Epoch 94/125, Training Loss: 0.3992
# Validation Accuracy: 85.44%
# Epoch 95/125, Training Loss: 0.3968
# Validation Accuracy: 85.02%
# Epoch 96/125, Training Loss: 0.4024
# Validation Accuracy: 85.84%
# Epoch 97/125, Training Loss: 0.3925
# Validation Accuracy: 85.20%
# Epoch 98/125, Training Loss: 0.3949
# Validation Accuracy: 85.14%
# Epoch 99/125, Training Loss: 0.3959
# Validation Accuracy: 85.84%
# Epoch 100/125, Training Loss: 0.3978
# Validation Accuracy: 86.30%
# Epoch 101/125, Training Loss: 0.3970
# Validation Accuracy: 85.58%
# Epoch 102/125, Training Loss: 0.3986
# Validation Accuracy: 85.44%
# Epoch 103/125, Training Loss: 0.3993
# Validation Accuracy: 85.54%
# Epoch 104/125, Training Loss: 0.3923
# Validation Accuracy: 86.34%
# Epoch 105/125, Training Loss: 0.3945
# Validation Accuracy: 85.42%
# Epoch 106/125, Training Loss: 0.3936
# Validation Accuracy: 86.32%
# Epoch 107/125, Training Loss: 0.3934
# Validation Accuracy: 86.30%
# Epoch 108/125, Training Loss: 0.3897
# Validation Accuracy: 86.10%
# Epoch 109/125, Training Loss: 0.3897
# Validation Accuracy: 85.84%
# Epoch 110/125, Training Loss: 0.3881
# Validation Accuracy: 86.04%
# Epoch 111/125, Training Loss: 0.3887
# Validation Accuracy: 86.10%
# Epoch 112/125, Training Loss: 0.3871
# Validation Accuracy: 86.42%
# Epoch 113/125, Training Loss: 0.3875
# Validation Accuracy: 85.36%
# Epoch 114/125, Training Loss: 0.3882
# Validation Accuracy: 86.26%
# Epoch 115/125, Training Loss: 0.3855
# Validation Accuracy: 85.66%
# Epoch 116/125, Training Loss: 0.3878
# Validation Accuracy: 86.16%
# Epoch 117/125, Training Loss: 0.3888
# Validation Accuracy: 85.54%
# Epoch 118/125, Training Loss: 0.3867
# Validation Accuracy: 85.44%
# Epoch 119/125, Training Loss: 0.3883
# Validation Accuracy: 86.02%
# Epoch 120/125, Training Loss: 0.3845
# Validation Accuracy: 86.18%
# Epoch 121/125, Training Loss: 0.3844
# Validation Accuracy: 86.34%
# Epoch 122/125, Training Loss: 0.3823
# Validation Accuracy: 86.12%
# Epoch 123/125, Training Loss: 0.3843
# Validation Accuracy: 86.18%
# Epoch 124/125, Training Loss: 0.3882
# Validation Accuracy: 85.82%
# Epoch 125/125, Training Loss: 0.3794
# Validation Accuracy: 86.34%

# %%
import matplotlib.pyplot as plt

plt.plot(epoch_loss, label='training loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot(epoch_loss, label='training loss')
#       4 plt.show()
#
# NameError: name 'epoch_loss' is not defined
